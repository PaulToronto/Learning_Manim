# %% [markdown]
# <a href="https://colab.research.google.com/github/PaulToronto/Learning_Manim/blob/main/01_Tutorials_Quickstart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Tutorials - Quickstart
#
# https://docs.manim.community/en/stable/tutorials/quickstart.html

# %%
# 1. Install System Dependencies (Includes LaTeX for MathTex)
# !sudo apt update
# !sudo apt install libcairo2-dev \
    texlive texlive-latex-extra texlive-fonts-extra \
    texlive-latex-recommended texlive-science \
    tipa libpango1.0-dev ffmpeg

# 2. Install Manim and specific IPython version for stability
# !pip install manim IPython==8.21.0

# 3. Restart kernel (Run this once, then comment it out)
# exit()
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://cli.github.com/packages stable InRelease
# Hit:3 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:4 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 60 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libcairo2-dev is already the newest version (1.16.0-5ubuntu2).
# texlive is already the newest version (2021.20220204-1).
# texlive-fonts-extra is already the newest version (2021.20220204-1).
# texlive-latex-extra is already the newest version (2021.20220204-1).
# texlive-latex-recommended is already the newest version (2021.20220204-1).
# texlive-science is already the newest version (2021.20220204-1).
# tipa is already the newest version (2:1.3-21).
# libpango1.0-dev is already the newest version (1.50.6+ds-2ubuntu1).
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 60 not upgraded.
# Requirement already satisfied: manim in /usr/local/lib/python3.12/dist-packages (0.19.2)
# Requirement already satisfied: IPython==8.21.0 in /usr/local/lib/python3.12/dist-packages (8.21.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from IPython==8.21.0) (4.4.2)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.12/dist-packages (from IPython==8.21.0) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/dist-packages (from IPython==8.21.0) (0.2.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /usr/local/lib/python3.12/dist-packages (from IPython==8.21.0) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from IPython==8.21.0) (2.19.2)
# Requirement already satisfied: stack-data in /usr/local/lib/python3.12/dist-packages (from IPython==8.21.0) (0.6.3)
# Requirement already satisfied: traitlets>=5 in /usr/local/lib/python3.12/dist-packages (from IPython==8.21.0) (5.7.1)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from IPython==8.21.0) (4.9.0)
# Requirement already satisfied: av>=15.0 in /usr/local/lib/python3.12/dist-packages (from manim) (16.1.0)
# Requirement already satisfied: beautifulsoup4>=4.12 in /usr/local/lib/python3.12/dist-packages (from manim) (4.13.5)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.12/dist-packages (from manim) (8.3.1)
# Requirement already satisfied: cloup>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from manim) (3.0.8)
# Requirement already satisfied: isosurfaces>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from manim) (0.1.2)
# Requirement already satisfied: manimpango<1.0.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from manim) (0.6.1)
# Requirement already satisfied: mapbox-earcut>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from manim) (2.0.0)
# Requirement already satisfied: moderngl-window>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from manim) (3.1.1)
# Requirement already satisfied: moderngl<6.0.0,>=5.7.0 in /usr/local/lib/python3.12/dist-packages (from manim) (5.12.0)
# Requirement already satisfied: networkx>=2.6 in /usr/local/lib/python3.12/dist-packages (from manim) (3.6.1)
# Requirement already satisfied: numpy>=2.1 in /usr/local/lib/python3.12/dist-packages (from manim) (2.4.2)
# Requirement already satisfied: pillow>=11.0 in /usr/local/lib/python3.12/dist-packages (from manim) (11.3.0)
# Requirement already satisfied: pycairo<2.0.0,>=1.14 in /usr/local/lib/python3.12/dist-packages (from manim) (1.29.0)
# Requirement already satisfied: pydub>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from manim) (0.25.1)
# Requirement already satisfied: rich>=12.0.0 in /usr/local/lib/python3.12/dist-packages (from manim) (13.9.4)
# Requirement already satisfied: scipy>=1.13.0 in /usr/local/lib/python3.12/dist-packages (from manim) (1.16.3)
# Requirement already satisfied: screeninfo>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from manim) (0.8.1)
# Requirement already satisfied: skia-pathops>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from manim) (0.9.1)
# Requirement already satisfied: srt>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from manim) (3.5.3)
# Requirement already satisfied: svgelements>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from manim) (1.9.6)
# Requirement already satisfied: tqdm>=4.21.0 in /usr/local/lib/python3.12/dist-packages (from manim) (4.67.3)
# Requirement already satisfied: typing-extensions>=4.12.0 in /usr/local/lib/python3.12/dist-packages (from manim) (4.15.0)
# Requirement already satisfied: watchdog>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from manim) (6.0.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.12->manim) (2.8.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->IPython==8.21.0) (0.8.5)
# Requirement already satisfied: glcontext>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from moderngl<6.0.0,>=5.7.0->manim) (3.0.0)
# Requirement already satisfied: pyglet>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from moderngl-window>=2.0.0->manim) (2.1.13)
# Requirement already satisfied: pyglm<3,>=2.7.0 in /usr/local/lib/python3.12/dist-packages (from moderngl-window>=2.0.0->manim) (2.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->IPython==8.21.0) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit<3.1.0,>=3.0.41->IPython==8.21.0) (0.5.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.0.0->manim) (4.0.0)
# Requirement already satisfied: executing>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from stack-data->IPython==8.21.0) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from stack-data->IPython==8.21.0) (3.0.1)
# Requirement already satisfied: pure-eval in /usr/local/lib/python3.12/dist-packages (from stack-data->IPython==8.21.0) (0.2.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.0.0->manim) (0.1.2)

# %% [markdown]
# ## Imports

# %%
from manim import *
# Out:
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:300: SyntaxWarning: invalid escape sequence '\('
#   m = re.match('([su]([0-9]{1,2})p?) \(([0-9]{1,2}) bit\)$', token)
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:301: SyntaxWarning: invalid escape sequence '\('
#   m2 = re.match('([su]([0-9]{1,2})p?)( \(default\))?$', token)
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:310: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(flt)p?( \(default\))?$', token):
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:314: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(dbl)p?( \(default\))?$', token):

# %% [markdown]
# ## Animating a Circle

# %%
# %%manim -ql -v WARNING CreateCircle
#
# class CreateCircle(Scene):
#     def construct(self):
#         circle = Circle()
#         circle.set_fill(PINK, opacity=0.5)
#         self.play(Create(circle))
# Out:
# Manim Community v0.19.2
# <video controls autoplay loop style="max-width: 60%;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# ## Transforming a square into a circle

# %%
# %%manim -ql -v WARNING SquareToCircle
#
# class SquareToCircle(Scene):
#     def construct(self):
#         circle = Circle()
#         circle.set_fill(PINK, opacity=0.5)
#
#         square = Square()
#         square.rotate(PI / 4) # rotate counter-clockwise
#
#         self.play(Create(square))
#         self.play(Transform(square, circle))
#         self.play(FadeOut(square))
# Out:
# Manim Community v0.19.2
# <video controls autoplay loop style="max-width: 60%;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# ## Positioning `Mobjects`

# %%
# %%manim -qh -v WARNING SquareAndCircle
#
# class SquareAndCircle(Scene):
#     def construct(self):
#         # Create the grid
#         grid = NumberPlane().add_coordinates()
#         self.add(grid)
#
#         # Create the shapes
#         circle = Circle()
#         circle.set_fill(PINK, opacity=0.5)
#
#         square = Square()
#         square.set_fill(BLUE, opacity=0.5)
#
#         # Position the shapes
#         square.next_to(circle, RIGHT, buff=0.5)
#
#         # Animate
#         self.play(Create(circle),
#                   Create(square), )
# Out:
# Manim Community v0.19.2
# <video controls autoplay loop style="max-width: 60%;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# ## Using `.animate` syntax to animate mathods
#
# - When you prepend `.animate` to any method call that modifies a `Mobject`, the method becomes an animation which can be played using `self.play`

# %%
# %%manim -ql -v WARNING AnimatedSquareToCircle
#
# class AnimatedSquareToCircle(Scene):
#     def construct(self):
#         circle = Circle()
#         square = Square()
#
#         self.play(Create(square))
#         self.play(square.animate.rotate(PI / 4))
#         self.play(Transform(square, circle))
#         self.play(
#             square.animate.set_fill(PINK, opacity=0.5)
#         )
# Out:
# Manim Community v0.19.2
# <video controls autoplay loop style="max-width: 60%;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# ## Different rotations
#
# - The important point here is that `.animate` uses **linear interpolation** of the points
#     - It looks at the corners of the square at the state and the corners after the rotation and tries to move each corner in a **straight line** to the destination. Because the corners move through the centre of the square, rather than around it, the square looks like it is collapsing during the transition
# - `Rotate` is dedicated animation class.
#     - It doesn't just look at the start and end points. It specifically calculates a **circular path** for every point in the **Mobject** around a centre point.

# %%
# %%manim -ql -v WARNING DifferentRotations
#
# class DifferentRotations(Scene):
#     def construct(self):
#         grid = NumberPlane()
#         self.add(grid)
#
#         left_square = Square(color=BLUE, fill_opacity=0.7).shift(2 * LEFT)
#         right_square = Square(color=GREEN, fill_opacity=0.7).shift(2 * RIGHT)
#
#         self.play(
#             left_square.animate.rotate(PI),
#             Rotate(right_square, angle=PI),
#             run_time=2
#         )
# Out:
# Manim Community v0.19.2
# <video controls autoplay loop style="max-width: 60%;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# ## With `Rotate` you can change the **pivot point**
#
# - By default, it rotates around the object's centre.

# %%
# %%manim -ql -v WARNING RotateAboutPivot
#
# class RotateAboutPivot(Scene):
#     def construct(self):
#         grid = NumberPlane()
#         self.add(grid)
#
#         left_square = Square(color=BLUE, fill_opacity=0.7).shift(2 * LEFT)
#         right_square = Square(color=GREEN, fill_opacity=0.7).shift(2 * RIGHT)
#
#         self.play(
#             left_square.animate.rotate(PI),
#             Rotate(right_square, angle=PI, about_point=ORIGIN),
#             run_time=2
#         )
# Out:
# Manim Community v0.19.2
# <video controls autoplay loop style="max-width: 60%;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# ## Multiple Spins

# %%
# %%manim -ql -v WARNING MultipleSpins
#
# class MultipleSpins(Scene):
#     def construct(self):
#         grid = NumberPlane()
#         self.add(grid)
#         right_square = Square(color=GREEN, fill_opacity=0.7).shift(2 * RIGHT)
#
#         self.play(
#             Rotate(right_square, angle=2 * TAU),
#             run_time=10,
#             rate_func=linear
#         )
#
#         self.play(FadeOut(right_square))
# Out:
# Manim Community v0.19.2
# <video controls autoplay loop style="max-width: 60%;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# ## `Transform` vs `ReplacementTransform`
#
# ### The Rule of the Stage
#
# An object only exists in the video if it has been added to the scene. `Transform(source, target)` automatically adds the source to the scene if it isn't there, but it never adds the target.

# %%
# %%manim -ql -v WARNING TwoTransforms
#
# class TwoTransforms(Scene):
#     def construct(self):
#         grid = NumberPlane()
#         self.add(grid)
#
#         #self.transform()
#         #self.wait(5)
#         self.replacement_transform()
#         self.wait(5)
#
#     def transform(self):
#         a = Circle()
#         b = Square()
#         c = Triangle()
#
#         # a is added to the scene, looks like a square
#         self.play(Transform(a, b))
#         # b is added to the scene, looks like a triangle
#         self.play(Transform(b, c))
#         # only a fades out, so the triangle remains
#         self.play(FadeOut(a))
#
#     def replacement_transform(self):
#         a = Circle()
#         b = Square()
#         c = Triangle()
#
#         self.play(ReplacementTransform(a, b))
#         self.play(ReplacementTransform(b, c))
#         self.play(FadeOut(c))
# Out:
# Manim Community v0.19.2
# <video controls autoplay loop style="max-width: 60%;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
# %%manim -ql -v WARNING TransformCycle
#
# class TransformCycle(Scene):
#     def construct(self):
#         a = Circle()
#         t1 = Square()
#         t2 = Triangle()
#
#         self.add(a)
#         self.wait(5)
#
#         for t in [t1, t2]:
#             self.play(Transform(a, t))
#
#         self.wait(5)
# Out:
# Manim Community v0.19.2
# <video controls autoplay loop style="max-width: 60%;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# ## `add_foreground_mobjects()`
#
# In the web development world, you solve overlap with z-index. In Manim, the order of objects is usually determined by the order they were added to the scene (the last one added is on top).
#
# However, during complex animations like Transform, objects can sometimes "slip" behind others, especially backgrounds or grids. `self.add_foreground_mobjects()` effectively pulls an object out of the standard stack and pins it to the very top layer.
#
# - Use add_foreground_mobjects: When you have a "static" element (like a title, a label, or a specific coordinate point) that must never be covered by moving animations, regardless of when they are created.

# %%
# %%manim -ql -v WARNING ZIndexExample
#
# class ZIndexExample(Scene):
#     def construct(self):
#         grid = NumberPlane()
#         circle = Circle(fill_opacity=1, color=BLUE)
#         square = Square(fill_opacity=1, color=RED).shift(UP * 0.5)
#
#         # Ensures circle stays visible even if
#         # the square moves "over" it in the code order
#         self.add_foreground_mobject(circle)
#
#         self.add(grid)
#         self.play(Create(circle), Create(square))
#         self.wait(5)
# Out:
# Manim Community v0.19.2
# <video controls autoplay loop style="max-width: 60%;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# ## There is no `add_background_mobjects()` so we use `set_z_index(-1)`

# %%
# %%manim -ql -v WARNING BackgroundExample
#
# class BackgroundExample(Scene):
#     def construct(self):
#         # 1. Start with a solid object
#         square = Square(fill_opacity=1, color=BLUE)
#         self.add(square)
#         self.wait(1)
#
#         # 2. You want to bring the grid "behind" the square
#         grid = NumberPlane().set_z_index(-1)
#
#         # 3. Fade it in. I will be under the square
#         self.play(FadeIn(grid))
# Out:
# Manim Community v0.19.2
# <video controls autoplay loop style="max-width: 60%;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
Fr
